# %%
#載入 numpy, 提供亂數資料與數學式, 
import numpy as np
# 載入 matplotlib
import matplotlib.pyplot as plt

x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# 設定雙格畫板大小
plt.subplot(2, 1, 1)
plt.plot(x, y_sin)
plt.title("Sine")

# 設定雙格畫板大小
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title("Cosine")

plt.show()

# %%
# 條型圖：Bar Plots

# 長條圖主要用來呈現兩個維度的資料，一個為X軸另一個則為Y軸(當然這邊指的是二維的狀況，較為常見)
# 主要用來呈現兩個維度的資料
# 問題：嘗試通過添加紅色條形標籤重現右側的圖形。
 #配置12 組 Bar
n = 12 
X = np.arange(n)
w = 20
h = 10
 #給定數學運算式
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
plt.subplots(figsize=(20, 10))
plt.subplot(1, 2, 2)
#指定上半部繪製區域, 給定 Bar 顏色, 邊界顏色
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
# +Y 指的是 XY 四象限的第一象限
# -Y 指的是 XY 四象限的第二象限
plt.bar(X, -Y1, facecolor='#ff9999', edgecolor='white')

'''
#在此coding
#指定下半部繪製區域, 給定 Bar 顏色, 邊界顏色
#顏色除了用色標外, 也可以用顏色文字描述, red: 紅色
'''

 #設定繪圖圖示區間
for x,y in zip(X,Y1):
    plt.text(x, y+0.05, '%.2f' % y, ha='center', va= 'center')
#     plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,-Y1):
    plt.text(x, y-0.05, '%.2f' % y, ha='center', va= 'center', color='red')

 #設定Y軸區間
plt.ylim(-1.25,+1.25)
plt.show()
# Out:
# (-1.25, 1.25)

# %%
# 軸圖進階

# 但是可以將圖放置在圖中的任何位置。因此，如果要在較大的圖中放置較小的圖，則可以使用軸。
# 特別提醒：tick 刻度線定位器
# 問題：使用 tick

# %%
plt.rcParams["figure.figsize"] = (10, 12)

'''
#決定第二層框


#決定第三層框


#決定第四層框

'''


# #決定第三層框
# plt.axes([0.25,0.25,.2,.075])
# plt.xticks([]), plt.yticks([])
# plt.text(0.5,0.25, 'axes([0.25,0.25,.2,.075])',ha='center',va='center',size=12,alpha=.5)

# #決定第四層框
# plt.axes([0.25,0.35,.2,.1])
# plt.xticks([]), plt.yticks([])
# plt.text(0.5,0.35, 'axes([0.4,0.4,.5,.5])',ha='center',va='center',size=12,alpha=.5)
fig = plt.figure()
#決定底框
plt.axes([0.1,0.1,.5,.5])
#給定刻度, 若不給定值, 圖的周邊無文字
plt.xticks([0,4,8,10, 12])
plt.yticks([0,.2,.4,.6,.8])
plt.text(0.1,0.1, 'range 0 - 11',ha='center',va='center',size=16,alpha=.5)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.title("title")
plt.xlabel('x-axis')
plt.ylabel('y-axis')

# # 決定第二層框
plt.axes([0.4,0.4,.2,.2])
plt.xticks([]), plt.yticks([])
plt.text(0,0.1, 'axes([0.4,0.4,.2,.2])',ha='left',va='center',size=14,alpha=1)
plt.bar(X, -Y1, facecolor='#ff9999', edgecolor='white')

fig.set_figheight(6)
fig.set_figwidth(12)
plt.show()
